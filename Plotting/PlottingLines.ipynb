# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\chait\appdata\local\programs\python\python39\lib\site-packages (3.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\chait\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chait\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\chait\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\chait\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\chait\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (8.3.2)
# Requirement already satisfied: numpy>=1.16 in c:\users\chait\appdata\local\programs\python\python39\lib\site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: six in c:\users\chait\appdata\local\programs\python\python39\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.arange(-5, 5, 0.1)
y = np.square(x)
plt.plot(x, y)
plt.title('$y=x^2$')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
y2 = x ** 3
plt.figure(figsize=(12, 5))
plt.plot(x, y, label="$y=x^2$")
plt.plot(x, y2, label="y=x^3")
plt.title('powers of x')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()
plt.show()
plt.savefig("figure1.png")
