# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
# loc is label-based, which means that you have to specify rows and columns based on their row and column labels.

# iloc is integer position-based, so you have to specify rows and columns by their integer position values 
# (0-based integer position).

# %%
df = df.sample(frac=1)
df.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 590          591         0       3
# 151          152         1       1
# 41            42         0       2
# 359          360         1       3
# 299          300         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 590                               Rintamaki, Mr. Matti    male  35.0      0
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 359                  Mockler, Miss. Helen Mary "Ellie"  female   NaN      0
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
#
#      Parch             Ticket      Fare    Cabin Embarked
# 590      0  STON/O 2. 3101273    7.1250      NaN        S
# 151      0             113776   66.6000       C2        S
# 41       0              11668   21.0000      NaN        S
# 359      0             330980    7.8792      NaN        Q
# 299      1           PC 17558  247.5208  B58 B60        C

# %%
df.loc[4]
# Out:
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 4, dtype: object

# %%
df.iloc[4]
# Out:
# PassengerId                                                300
# Survived                                                     1
# Pclass                                                       1
# Name           Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# Sex                                                     female
# Age                                                       50.0
# SibSp                                                        0
# Parch                                                        1
# Ticket                                                PC 17558
# Fare                                                  247.5208
# Cabin                                                  B58 B60
# Embarked                                                     C
# Name: 299, dtype: object

# %%
df.loc[[4, 5], "Sex"]
# Out:
# 4    male
# 5    male
# Name: Sex, dtype: object

# %%
df.iloc[[4, 5], 4]
# Out:
# 299    female
# 289    female
# Name: Sex, dtype: object

# %%
df.loc[[869, 95], "Sex"]
# Out:
# 869    male
# 95     male
# Name: Sex, dtype: object

# %%
female_df = df[df.Sex=='female']
female_df.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 151          152         1       1
# 41            42         0       2
# 359          360         1       3
# 299          300         1       1
# 289          290         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 359                  Mockler, Miss. Helen Mary "Ellie"  female   NaN      0
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 289                               Connolly, Miss. Kate  female  22.0      0
#
#      Parch    Ticket      Fare    Cabin Embarked
# 151      0    113776   66.6000       C2        S
# 41       0     11668   21.0000      NaN        S
# 359      0    330980    7.8792      NaN        Q
# 299      1  PC 17558  247.5208  B58 B60        C
# 289      0    370373    7.7500      NaN        Q

# %%
female_df.iloc[4]
# Out:
# PassengerId                     290
# Survived                          1
# Pclass                            3
# Name           Connolly, Miss. Kate
# Sex                          female
# Age                            22.0
# SibSp                             0
# Parch                             0
# Ticket                       370373
# Fare                           7.75
# Cabin                           NaN
# Embarked                          Q
# Name: 289, dtype: object

# %%
female_df.loc[289]
# Out:
# PassengerId                     290
# Survived                          1
# Pclass                            3
# Name           Connolly, Miss. Kate
# Sex                          female
# Age                            22.0
# SibSp                             0
# Parch                             0
# Ticket                       370373
# Fare                           7.75
# Cabin                           NaN
# Embarked                          Q
# Name: 289, dtype: object

# %%
female_df.loc[:289]
# Out:
#      PassengerId  Survived  Pclass  \
# 151          152         1       1
# 41            42         0       2
# 359          360         1       3
# 299          300         1       1
# 289          290         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 359                  Mockler, Miss. Helen Mary "Ellie"  female   NaN      0
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 289                               Connolly, Miss. Kate  female  22.0      0
#
#      Parch    Ticket      Fare    Cabin Embarked
# 151      0    113776   66.6000       C2        S
# 41       0     11668   21.0000      NaN        S
# 359      0    330980    7.8792      NaN        Q
# 299      1  PC 17558  247.5208  B58 B60        C
# 289      0    370373    7.7500      NaN        Q

# %%
female_df.iloc[:5]
# Out:
#      PassengerId  Survived  Pclass  \
# 151          152         1       1
# 41            42         0       2
# 359          360         1       3
# 299          300         1       1
# 289          290         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 359                  Mockler, Miss. Helen Mary "Ellie"  female   NaN      0
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 289                               Connolly, Miss. Kate  female  22.0      0
#
#      Parch    Ticket      Fare    Cabin Embarked
# 151      0    113776   66.6000       C2        S
# 41       0     11668   21.0000      NaN        S
# 359      0    330980    7.8792      NaN        Q
# 299      1  PC 17558  247.5208  B58 B60        C
# 289      0    370373    7.7500      NaN        Q

# %%
female_df.iloc[:4][['Survived', 'Name', 'Pclass']]
# Out:
#      Survived                                               Name  Pclass
# 151         1                  Pears, Mrs. Thomas (Edith Wearne)       1
# 41          0  Turpin, Mrs. William John Robert (Dorothy Ann ...       2
# 359         1                  Mockler, Miss. Helen Mary "Ellie"       3
# 299         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)       1

# %%
female_df.loc[female_df['Pclass']==3, ['Survived', 'Name', 'Pclass']]
# Out:
#      Survived                                        Name  Pclass
# 359         1           Mockler, Miss. Helen Mary "Ellie"       3
# 289         1                        Connolly, Miss. Kate       3
# 578         0            Caram, Mrs. Joseph (Maria Elias)       3
# 727         1                    Mannion, Miss. Margareth       3
# 251         0  Strom, Mrs. Wilhelm (Elna Matilda Persson)       3
# ..        ...                                         ...     ...
# 483         1                      Turkula, Mrs. (Hedwig)       3
# 875         1            Najib, Miss. Adele Kiamie "Jane"       3
# 780         1                        Ayoub, Miss. Banoura       3
# 10          1             Sandstrom, Miss. Marguerite Rut       3
# 474         0                 Strandberg, Miss. Ida Sofia       3
#
# [144 rows x 3 columns]
